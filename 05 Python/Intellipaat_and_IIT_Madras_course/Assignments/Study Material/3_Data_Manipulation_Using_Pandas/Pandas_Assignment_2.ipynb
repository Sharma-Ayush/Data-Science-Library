# %%
import pandas as pd
import numpy as np

# %%
churn = pd.read_csv('customer_churn-1.csv')

# %% [markdown]
# # Problem Statement:

# %% [markdown]
# You work in XYZ Corporation as a Data Analyst. Your corporation has told you to
# analyze the customer_churn dataset with various functions.

# %% [markdown]
# ### Tasks To Be Performed:

# %% [markdown]
# 1. Now select the rows from 20th index till 200th index(exclusive),and
# columns from 2nd index till 15th index value.

# %%
Cols = churn.columns

# %%
churn.iloc[20:200, 2:16]
# Out:
#      SeniorCitizen Partner Dependents  tenure PhoneService     MultipleLines  \
# 20               1      No         No       1           No  No phone service
# 21               0     Yes         No      12          Yes                No
# 22               0      No         No       1          Yes                No
# 23               0     Yes         No      58          Yes               Yes
# 24               0     Yes        Yes      49          Yes                No
# ..             ...     ...        ...     ...          ...               ...
# 195              0     Yes         No      20          Yes                No
# 196              0     Yes        Yes      24          Yes               Yes
# 197              0      No         No      59          Yes               Yes
# 198              0     Yes        Yes      72          Yes               Yes
# 199              0      No        Yes       1          Yes                No
#
# ...

# %% [markdown]
# or

# %%
churn.loc[20:199, Cols[2:16]]
# Out:
#      SeniorCitizen Partner Dependents  tenure PhoneService     MultipleLines  \
# 20               1      No         No       1           No  No phone service
# 21               0     Yes         No      12          Yes                No
# 22               0      No         No       1          Yes                No
# 23               0     Yes         No      58          Yes               Yes
# 24               0     Yes        Yes      49          Yes                No
# ..             ...     ...        ...     ...          ...               ...
# 195              0     Yes         No      20          Yes                No
# 196              0     Yes        Yes      24          Yes               Yes
# 197              0      No         No      59          Yes               Yes
# 198              0     Yes        Yes      72          Yes               Yes
# 199              0      No        Yes       1          Yes                No
#
# ...

# %% [markdown]
# or

# %%
churn[Cols[2:16]][20:200]
# Out:
#      SeniorCitizen Partner Dependents  tenure PhoneService     MultipleLines  \
# 20               1      No         No       1           No  No phone service
# 21               0     Yes         No      12          Yes                No
# 22               0      No         No       1          Yes                No
# 23               0     Yes         No      58          Yes               Yes
# 24               0     Yes        Yes      49          Yes                No
# ..             ...     ...        ...     ...          ...               ...
# 195              0     Yes         No      20          Yes                No
# 196              0     Yes        Yes      24          Yes               Yes
# 197              0      No         No      59          Yes               Yes
# 198              0     Yes        Yes      72          Yes               Yes
# 199              0      No        Yes       1          Yes                No
#
# ...
